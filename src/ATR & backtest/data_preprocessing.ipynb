# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = '545 Group'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['EECS_545_Proposal (1).gdoc', 'EECS_545_Proposal.gdoc', 'EECS_545_Proposal.pdf', 'Applying Deep Learning and NLP for Stock Price Prediction.docx', 'AA.csv', 'ATR (k1, k2, N).ipynb', 'utils.ipynb', 'sp500_merged.xlsx', 'data_processing.py', 'ts_backtest_framework1.ipynb', 'data_preprocessing.ipynb']

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

# %%
os.chdir(GOOGLE_DRIVE_PATH)

# %%
import yfinance as yf

sp500 = yf.Ticker("^GSPC")

# Get data for a specific date range
data = sp500.history(start="2020-01-01", end="2024-01-03")

# %%
from orgi.src.labeler import TripleBarrierLabeler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-d839a26b59c6> in <cell line: 0>()
# ----> 1 from orgi.src.labeler import TripleBarrierLabeler
#
# /content/drive/My Drive/545 Group/orgi/src/labeler.py in <module>
#       2 import pandas as pd
#       3
# ----> 4 from type import Labeler
#       5 from util.decorator import validate_columns
#       6
#
# ModuleNotFoundError: No module named 'type'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
